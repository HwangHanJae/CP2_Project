# %% [markdown]
# # 데이터 브릭스에 rawdata를 업로드 하기 위한 노트북
# 데이터브릭스에 한번에 업로드할 수 있는 용량 제한이 있기 때문에 rawdata를 나누어야 합니다.

# %%
import pandas as pd

# %%
data_path ='C:/Users/User/Desktop/AIB_13/CP2/raw_data/'
df= pd.read_csv(data_path+'2019-Oct.csv')
df.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-10-01 00:00:00 UTC       view    44600062  2103807459595387724
# 1  2019-10-01 00:00:00 UTC       view     3900821  2053013552326770905
# 2  2019-10-01 00:00:01 UTC       view    17200506  2053013559792632471
# 3  2019-10-01 00:00:01 UTC       view     1307067  2053013558920217191
# 4  2019-10-01 00:00:04 UTC       view     1004237  2053013555631882655
#
#                          category_code     brand    price    user_id  \
# 0                                  NaN  shiseido    35.79  541312140
# 1  appliances.environment.water_heater      aqua    33.20  554748717
# 2           furniture.living_room.sofa       NaN   543.10  519107250
# 3                   computers.notebook    lenovo   251.74  550050854
# 4               electronics.smartphone     apple  1081.98  535871217
#
#                            user_session
# 0  72d76fde-8bb3-4e00-8c23-a032dfed738c
# 1  9333dfbd-b87a-4708-9857-6336556b0fcc
# ...

# %%
df.tail()
# Out:
#                        event_time event_type  product_id          category_id  \
# 42448759  2019-10-31 23:59:58 UTC       view     2300275  2053013560530830019
# 42448760  2019-10-31 23:59:58 UTC       view    10800172  2053013554994348409
# 42448761  2019-10-31 23:59:58 UTC       view     5701038  2053013553970938175
# 42448762  2019-10-31 23:59:59 UTC       view    21407424  2053013561579406073
# 42448763  2019-10-31 23:59:59 UTC       view    13300120  2053013557166998015
#
#                      category_code      brand   price    user_id  \
# 42448759  electronics.camera.video      gopro  527.40  537931532
# 42448760                       NaN    redmond   61.75  527322328
# 42448761   auto.accessories.player    kenwood  128.70  566280422
# 42448762        electronics.clocks     tissot  689.85  513118352
# 42448763                       NaN  swisshome  155.73  525266378
#
#                                   user_session
# 42448759  22c57267-da98-4f28-9a9c-18bb5b385193
# ...

# %%
len(df)
# Out:
# 42448764

# %%
len(df) / 4
# Out:
# 10612191.0

# %%
value = 10612191

# %%
df.iloc[:value, ].head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-10-01 00:00:00 UTC       view    44600062  2103807459595387724
# 1  2019-10-01 00:00:00 UTC       view     3900821  2053013552326770905
# 2  2019-10-01 00:00:01 UTC       view    17200506  2053013559792632471
# 3  2019-10-01 00:00:01 UTC       view     1307067  2053013558920217191
# 4  2019-10-01 00:00:04 UTC       view     1004237  2053013555631882655
#
#                          category_code     brand    price    user_id  \
# 0                                  NaN  shiseido    35.79  541312140
# 1  appliances.environment.water_heater      aqua    33.20  554748717
# 2           furniture.living_room.sofa       NaN   543.10  519107250
# 3                   computers.notebook    lenovo   251.74  550050854
# 4               electronics.smartphone     apple  1081.98  535871217
#
#                            user_session
# 0  72d76fde-8bb3-4e00-8c23-a032dfed738c
# 1  9333dfbd-b87a-4708-9857-6336556b0fcc
# ...

# %%
df.iloc[:value, ].tail()
# Out:
#                        event_time event_type  product_id          category_id  \
# 10612186  2019-10-09 08:10:24 UTC       view    25400261  2053013561604571899
# 10612187  2019-10-09 08:10:24 UTC       view     1004767  2053013555631882655
# 10612188  2019-10-09 08:10:24 UTC       view    26018993  2053013562560873263
# 10612189  2019-10-09 08:10:24 UTC       view    12712984  2053013553559896355
# 10612190  2019-10-09 08:10:24 UTC       view    15100382  2053013557024391671
#
#                    category_code     brand   price    user_id  \
# 10612186                     NaN       NaN   17.54  558355117
# 10612187  electronics.smartphone   samsung  250.96  558357032
# 10612188                     NaN       NaN    8.88  527558332
# 10612189                     NaN     hifly   55.09  512856997
# 10612190                     NaN  helvetia  910.68  517278870
#
#                                   user_session
# 10612186  7f069695-f729-48d5-b91e-ab3799cc90a9
# ...

# %%
df.iloc[:value, ].to_parquet('split_data1.parquet')
df.iloc[:value, ].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10612191 entries, 0 to 10612190
# Data columns (total 9 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   event_time     object
#  1   event_type     object
#  2   product_id     int64
#  3   category_id    int64
#  4   category_code  object
#  5   brand          object
#  6   price          float64
#  7   user_id        int64
#  8   user_session   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 728.7+ MB

# %%
value2 = 10612191 * 2

# %%
df.iloc[value : value2, ].head()
# Out:
#                        event_time event_type  product_id          category_id  \
# 10612191  2019-10-09 08:10:24 UTC       view    12300451  2053013556311359947
# 10612192  2019-10-09 08:10:24 UTC       view     3601524  2053013563810775923
# 10612193  2019-10-09 08:10:24 UTC       view    12703206  2053013553559896355
# 10612194  2019-10-09 08:10:24 UTC       view     1480452  2053013561092866779
# 10612195  2019-10-09 08:10:24 UTC       view     5100816  2053013553375346967
#
#                       category_code     brand   price    user_id  \
# 10612191   construction.tools.drill     crown   39.82  558357029
# 10612192  appliances.kitchen.washer   samsung  398.95  536555597
# 10612193                        NaN  cordiant   84.69  514980449
# 10612194          computers.desktop    pulser  411.83  521199762
# 10612195                        NaN    xiaomi   28.73  515415702
#
#                                   user_session
# 10612191  e09a1396-f666-437a-9f12-206be4f1e714
# ...

# %%
df.iloc[value : value2, ].tail()
# Out:
#                        event_time event_type  product_id          category_id  \
# 21224377  2019-10-16 12:04:37 UTC       view     4501525  2053013563877884791
# 21224378  2019-10-16 12:04:37 UTC       view    13200136  2053013557192163841
# 21224379  2019-10-16 12:04:37 UTC       view    31000205  2055156924315337497
# 21224380  2019-10-16 12:04:37 UTC       view     7600053  2053013552821698803
# 21224381  2019-10-16 12:04:37 UTC       view     7900918  2053013556487520725
#
#                     category_code    brand   price    user_id  \
# 21224377   appliances.kitchen.hob    midea  130.54  514337460
# 21224378    furniture.bedroom.bed      NaN  123.81  515791841
# 21224379                      NaN   deeper  149.30  518696237
# 21224380                      NaN  tp-link   24.58  513996709
# 21224381  furniture.kitchen.chair     joie  102.71  560842110
#
#                                   user_session
# 21224377  854c029e-3e6a-4a7b-98ed-b0cdff540973
# ...

# %%
df.iloc[value : value2, ].to_parquet('split_data2.parquet')
df.iloc[value : value2, ].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10612191 entries, 10612191 to 21224381
# Data columns (total 9 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   event_time     object
#  1   event_type     object
#  2   product_id     int64
#  3   category_id    int64
#  4   category_code  object
#  5   brand          object
#  6   price          float64
#  7   user_id        int64
#  8   user_session   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 728.7+ MB

# %%
value3 = value2 + 10612191

# %%
df.iloc[value2 : value3, ].head()
# Out:
#                        event_time event_type  product_id          category_id  \
# 21224382  2019-10-16 12:04:37 UTC       view     1003317  2053013555631882655
# 21224383  2019-10-16 12:04:37 UTC       view     2501929  2053013564003713919
# 21224384  2019-10-16 12:04:37 UTC       view     1004833  2053013555631882655
# 21224385  2019-10-16 12:04:37 UTC       cart     1004836  2053013555631882655
# 21224386  2019-10-16 12:04:37 UTC       view     7100040  2053013555464110485
#
#                     category_code    brand   price    user_id  \
# 21224382   electronics.smartphone    apple  952.15  560842739
# 21224383  appliances.kitchen.oven     asel   61.75  525817175
# 21224384   electronics.smartphone  samsung  172.17  515456548
# 21224385   electronics.smartphone  samsung  229.41  529758564
# 21224386    furniture.bedroom.bed      NaN  131.28  560843157
#
#                                   user_session
# 21224382  46f51dd2-dc85-4fdc-81f5-58e5b573fa6d
# ...

# %%
df.iloc[value2 : value3, ].tail()
# Out:
#                        event_time event_type  product_id          category_id  \
# 31836568  2019-10-23 17:52:15 UTC       view     4804434  2053013554658804075
# 31836569  2019-10-23 17:52:15 UTC       view     5900098  2053013560841208525
# 31836570  2019-10-23 17:52:15 UTC       view    17200559  2053013559792632471
# 31836571  2019-10-23 17:52:15 UTC       view     3400032  2053013555178897795
# 31836572  2019-10-23 17:52:15 UTC       view     1004872  2053013555631882655
#
#                         category_code    brand   price    user_id  \
# 31836568  electronics.audio.headphone   xiaomi   46.31  516150392
# 31836569                          NaN   garmin  632.63  514200296
# 31836570   furniture.living_room.sofa      NaN  591.78  527542198
# 31836571                          NaN  redmond  149.04  519654117
# 31836572       electronics.smartphone  samsung  280.87  512620453
#
#                                   user_session
# 31836568  1a9487d9-c9b7-49db-8945-dde8c12334ae
# ...

# %%
df.iloc[value2 : value3, ].to_parquet('split_data3.parquet')
df.iloc[value2 : value3, ].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10612191 entries, 21224382 to 31836572
# Data columns (total 9 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   event_time     object
#  1   event_type     object
#  2   product_id     int64
#  3   category_id    int64
#  4   category_code  object
#  5   brand          object
#  6   price          float64
#  7   user_id        int64
#  8   user_session   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 728.7+ MB

# %%
#######

# %%
df.iloc[value3 : , ].head()
# Out:
#                        event_time event_type  product_id          category_id  \
# 31836573  2019-10-23 17:52:15 UTC   purchase     1004785  2053013555631882655
# 31836574  2019-10-23 17:52:15 UTC       view     1005099  2053013555631882655
# 31836575  2019-10-23 17:52:15 UTC       view     1701420  2053013553031414015
# 31836576  2019-10-23 17:52:15 UTC       view     1701392  2053013553031414015
# 31836577  2019-10-23 17:52:15 UTC       view     2900759  2053013554776244595
#
#                           category_code       brand   price    user_id  \
# 31836573         electronics.smartphone      huawei  270.42  518906847
# 31836574         electronics.smartphone     samsung  141.32  563420731
# 31836575  computers.peripherals.monitor     samsung  244.51  514289643
# 31836576  computers.peripherals.monitor        acer  135.14  541062608
# 31836577   appliances.kitchen.microwave  electrolux  613.06  512758245
#
#                                   user_session
# ...

# %%
df.iloc[value3 : , ].tail()
# Out:
#                        event_time event_type  product_id          category_id  \
# 42448759  2019-10-31 23:59:58 UTC       view     2300275  2053013560530830019
# 42448760  2019-10-31 23:59:58 UTC       view    10800172  2053013554994348409
# 42448761  2019-10-31 23:59:58 UTC       view     5701038  2053013553970938175
# 42448762  2019-10-31 23:59:59 UTC       view    21407424  2053013561579406073
# 42448763  2019-10-31 23:59:59 UTC       view    13300120  2053013557166998015
#
#                      category_code      brand   price    user_id  \
# 42448759  electronics.camera.video      gopro  527.40  537931532
# 42448760                       NaN    redmond   61.75  527322328
# 42448761   auto.accessories.player    kenwood  128.70  566280422
# 42448762        electronics.clocks     tissot  689.85  513118352
# 42448763                       NaN  swisshome  155.73  525266378
#
#                                   user_session
# 42448759  22c57267-da98-4f28-9a9c-18bb5b385193
# ...

# %%
df.iloc[value3 : , ].to_parquet('split_data4.parquet')
df.iloc[value3 : , ].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10612191 entries, 31836573 to 42448763
# Data columns (total 9 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   event_time     object
#  1   event_type     object
#  2   product_id     int64
#  3   category_id    int64
#  4   category_code  object
#  5   brand          object
#  6   price          float64
#  7   user_id        int64
#  8   user_session   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 728.7+ MB
