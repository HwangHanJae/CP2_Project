# %%
# !pip install implicit
# !pip install fastparquet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting implicit
#   Downloading implicit-0.6.1-cp37-cp37m-manylinux2014_x86_64.whl (18.6 MB)
#      |████████████████████████████████| 18.6 MB 4.5 MB/s
# Requirement already satisfied: scipy>=0.16 in /usr/local/lib/python3.7/dist-packages (from implicit) (1.7.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from implicit) (4.64.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from implicit) (1.21.6)
# Installing collected packages: implicit
# Successfully installed implicit-0.6.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fastparquet
#   Downloading fastparquet-0.8.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 5.1 MB/s
# Requirement already satisfied: fsspec in /usr/local/lib/python3.7/dist-packages (from fastparquet) (2022.8.2)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.7/dist-packages (from fastparquet) (1.21.6)
# Collecting cramjam>=2.3.0
#   Downloading cramjam-2.5.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 50.9 MB/s
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from fastparquet) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.0->fastparquet) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.0->fastparquet) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.1.0->fastparquet) (1.15.0)
# Installing collected packages: cramjam, fastparquet
# Successfully installed cramjam-2.5.0 fastparquet-0.8.1

# %%
import pandas as pd
import numpy as np
import scipy.sparse as sparse
import random
import implicit

from tqdm import tqdm

# %%
try:
  path = 'C:/Users/User/Desktop/AIB_13/CP2/data/'
  df = pd.read_parquet(path + 'light_2019-Oct.parquet', engine='fastparquet')
except:
  path = '/content/drive/MyDrive/CP2/data/'
  df = pd.read_parquet(path + 'light_2019-Oct.parquet', engine='fastparquet')

# %%
df.head()
# Out:
#                 event_time event_type  product_id  category_id  \
# 0  2019-10-01 00:00:00 UTC       view    44600062   -251657396
# 1  2019-10-01 00:00:00 UTC       view     3900821   -780140327
# 2  2019-10-01 00:00:01 UTC       view    17200506  -1904213353
# 3  2019-10-01 00:00:01 UTC       view     1307067   1518338663
# 4  2019-10-01 00:00:04 UTC       view     1004237  -1769995873
#
#                          category_code     brand        price    user_id  \
# 0                                  NaN  shiseido    35.790001  541312140
# 1  appliances.environment.water_heater      aqua    33.200001  554748717
# 2           furniture.living_room.sofa       NaN   543.099976  519107250
# 3                   computers.notebook    lenovo   251.740005  550050854
# 4               electronics.smartphone     apple  1081.979980  535871217
#
#                            user_session
# 0  72d76fde-8bb3-4e00-8c23-a032dfed738c
# 1  9333dfbd-b87a-4708-9857-6336556b0fcc
# 2  566511c2-e2e3-422b-b695-cf8e6e792ca8
# 3  7c90fc70-0e80-4590-96f3-13c02c18c713
# 4  c6bd7419-2748-4c56-95b4-8cec9ff8b80d

# %%
df.loc[df['user_id'] ==200673532]
# Out:
#                        event_time event_type  product_id  category_id  \
# 12391638  2019-10-10 15:02:36 UTC       view     6701171   1140851025
# 14777866  2019-10-12 07:58:37 UTC       view     6701171   1140851025
# 15315900  2019-10-12 14:47:07 UTC       view     6501011   1048576331
# 16898616  2019-10-13 14:26:21 UTC       view     6501011   1048576331
#
#                              category_code    brand      price    user_id  \
# 12391638   computers.components.videocards  sinotex  99.419998  200673532
# 14777866   computers.components.videocards  sinotex  99.419998  200673532
# 15315900  computers.components.motherboard   asrock  73.360001  200673532
# 16898616  computers.components.motherboard   asrock  73.360001  200673532
#
#                                   user_session
# 12391638  08b03c3c-bd1b-4268-a012-91ca4d0e5030
# 14777866  4957f400-27cb-45e9-8d37-cd720aa40725
# 15315900  7b9c574c-6c0e-4dc8-a993-e3ff0f750d21
# 16898616  7b9c574c-6c0e-4dc8-a993-e3ff0f750d21

# %%
df.loc[df['user_id'] ==184265397]
# Out:
#                        event_time event_type  product_id  category_id  \
# 4799279   2019-10-04 17:44:37 UTC       view     6902133  -1384119625
# 4800257   2019-10-04 17:45:18 UTC       view     6902133  -1384119625
# 4808012   2019-10-04 17:50:50 UTC       view     6902303  -1384119625
# 4808317   2019-10-04 17:51:04 UTC       view     6902303  -1384119625
# 20218302  2019-10-15 17:18:59 UTC       view    27400002   1694499675
# 20219228  2019-10-15 17:19:28 UTC       view    27400002   1694499675
#
#                         category_code   brand       price    user_id  \
# 4799279   furniture.living_room.chair    joie  143.889999  184265397
# 4800257   furniture.living_room.chair    joie  143.889999  184265397
# 4808012   furniture.living_room.chair    joie  111.459999  184265397
# 4808317   furniture.living_room.chair    joie  111.459999  184265397
# 20218302                          NaN  oral-b   79.769997  184265397
# 20219228                          NaN  oral-b   79.769997  184265397
#
#                                   user_session
# 4799279   2c5d0468-32e1-42f7-9b4e-b17c1d387247
# 4800257   2c5d0468-32e1-42f7-9b4e-b17c1d387247
# 4808012   2c5d0468-32e1-42f7-9b4e-b17c1d387247
# 4808317   2c5d0468-32e1-42f7-9b4e-b17c1d387247
# 20218302  c4ddb5b7-3185-453b-8e02-45d48a9775be
# 20219228  c4ddb5b7-3185-453b-8e02-45d48a9775be
